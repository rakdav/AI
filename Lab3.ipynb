# %%
from my_package import  module1,module2
a=int(input("Введите первое число:"))
b=int(input("Введите второе число:"))
print(a,"+",b,"=",module1.sum(a,b))
print(a,"-",b,"=",module2.sub(a,b))
# Out:
# 6 + 6 = 12
# 6 - 6 = 0
